# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

# %%
original_img = cv2.imread('bird.jpg')

# %%
original_img.shape
# Out:
# (2657, 4724, 3)

# %%
plt.imshow(original_img)

# %%
img = cv2.imread('bird.jpg', cv2.IMREAD_GRAYSCALE)

# %%
img.shape
# Out:
# (2657, 4724)

# %%
plt.imshow(img, cmap = 'gray')

# %%
filter = np.ones((11, 11))/255
filter
# Out:
# array([[0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157],
#        [0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157, 0.00392157, 0.00392157, 0.00392157, 0.00392157,
#         0.00392157],
# ...

# %%
blur = signal.convolve2d(img, filter, boundary = 'symm', mode = 'same')

# %%
plt.figure()
plt.subplot(121)
plt.imshow(img,cmap='gray')

plt.subplot(122)
plt.imshow(blur,cmap='gray')

plt.show()

# %%
x_mask = np.array([[-1,0,1],
                   [-1,0,1],
                   [-1,0,1]])

# %%
y_mask = np.array([[-1,-1,-1],
                   [0,0,0],
                   [1,1,1]])

# %%
x_mask_img = signal.convolve2d(blur, x_mask, boundary = 'symm', mode = 'same')
y_mask_img = signal.convolve2d(blur, y_mask, boundary = 'symm', mode = 'same')

# %%
plt.figure()
plt.subplot(131)
plt.imshow(img,cmap='gray')

plt.subplot(132)
plt.imshow(x_mask_img,cmap='gray')

plt.subplot(133)
plt.imshow(y_mask_img,cmap='gray')
plt.show()

# %%
x_mask_img.shape
# Out:
# (2657, 4724)

# %%
x_mask
# Out:
# array([[-1,  0,  1],
#        [-1,  0,  1],
#        [-1,  0,  1]])

# %%
y_mask
# Out:
# array([[-1, -1, -1],
#        [ 0,  0,  0],
#        [ 1,  1,  1]])

# %%
GM = (x_mask_img**2 + y_mask_img**2)**0.5

# %%
plt.figure()
plt.subplot(121)
plt.imshow(img,cmap='gray')

plt.subplot(122)
plt.imshow(GM>0.5,cmap='gray')

plt.show()
